# %% [markdown]
# <a href="https://colab.research.google.com/github/iiturralde-bit/nose/blob/main/Adios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hola me llamo Ramón")
# Out:
# hola me llamo Ramón

# %%
try:
    user_input = input("Please enter a number: ")
    number = int(user_input)
    result = number * 10
    print(f"Your number multiplied by 10 is: {result}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
